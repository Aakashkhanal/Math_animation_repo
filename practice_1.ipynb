# %%
from manim import *
# Out:
# Manim Community v0.18.0

# %%
# %%manim -v WARNING -qm QuadraticEquation
#
# class QuadraticEquation(Scene):
#    def construct(self):
#         # Create the quadratic equation
#         quadratic_eq = MathTex("ax^2 + bx + c = 0")
#         quadratic_eq.scale(1.5)
#
#         # Position the quadratic equation in the center
#         quadratic_eq.move_to(ORIGIN)
#         self.play(Write(quadratic_eq))
#         self.wait(1)
#
#         # Move the quadratic equation to the top-left corner
#         top_left = [-4, 3, 0]  # Top-left corner coordinates
#         self.play(quadratic_eq.animate.move_to(top_left))
#         self.wait(1)
#
#         # Create two roots of the quadratic equation
#         root1 = MathTex("x_1 = \\frac{-b + \\sqrt{b^2 - 4ac}}{2a}")
#         root2 = MathTex("x_2 = \\frac{-b - \\sqrt{b^2 - 4ac}}{2a}")
#
#         # Position the roots
#         root1.move_to([2, 1, 0])  # Right part for first root
#         root2.move_to([2, -1, 0])  # Right part for second root
#
#         # Create a single line going out from the center of the equation
#         middle_line = Line(start=quadratic_eq.get_right(), end=[1, 0, 0])
#
#         # Create two branching lines going to the two roots
#         branch_line1 = Line(start=[1, 0, 0], end=root1.get_left())
#         branch_line2 = Line(start=[1, 0, 0], end=root2.get_left())
#
#         # Draw the middle line first
#         self.play(Create(middle_line))
#         self.wait(0.5)
#
#         # Draw the two branches
#         self.play(Create(branch_line1), Create(branch_line2))
#         self.wait(1)
#
#         # Display the roots at the end of the branches
#         self.play(Write(root1), Write(root2))
#         self.wait(2)
# Out:
# <video src="media/jupyter/QuadraticEquation@2025-10-02@18-27-07.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### 1. First_day of posting Manim video

# %%
# %%manim -v WARNING -ql -r 1080,1920 SinAndCosFunctionPlot
# class SinAndCosFunctionPlot(Scene):
#     def construct(self):
#         axes = Axes(
#             x_range =[-10, 10.3,1],
#             y_range =[-1.5, 1.5,1],
#
#             x_axis_config={
#                 "numbers_to_include": np.arange(-10, 10.1, 2),
#                 "numbers_with_elongated_ticks": np.arange(-10, 10.1, 2)
#             },
#             tips=False
#         )
#         curve1 = axes.plot(lambda x: np.sin(x), color=BLUE)
#         curve2 = axes.plot(lambda x: np.cos(x), color=RED)
#         area = axes.get_area(curve1, x_range=[-3, 3], color=BLUE, opacity=0.5)
#
#         curve1_label1 = axes.get_graph_label(curve1, label="\\sin(x)", x_val=-10, direction=UP / 2)
#         curve1_label2 = axes.get_graph_label(curve2, label="\\cos(x)", x_val= -10, direction=DOWN)
#
#
#         self.play(Create(axes))
#         self.wait(1)
#         self.play( Create(curve1))
#         self.wait(1)
#         self.play( Create(curve2))
#         self.add(curve1_label2)
#         self.wait(1)
#         self.play( FadeOut(curve2),FadeOut(curve1_label2))
#         self.add(curve1_label1)
#         self.wait(1)
#         self.play(Create(area))
#         self.wait(2)
# Out:
# <video src="media/jupyter/SinAndCosFunctionPlot@2025-10-01@17-23-12.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING -ql -r 1080,1920 SinAndCosFunctionPlot2
# from manim import *
# import numpy as np
#
# class SinAndCosFunctionPlot2(Scene):
#     def construct(self):
#         text = Text("By Unknown Variable X", font_size=80, color=WHITE)
#         text.to_edge(UP).shift(UP*7)
#         text.set_color_by_gradient(BLUE, PURPLE, PINK)
#
#
#         axes = Axes(
#             x_range =[-10, 10.3,1],
#             y_range =[-1.5, 1.5,1],
#             x_axis_config={
#                 "numbers_to_include": np.arange(-10, 10.1, 2),
#                 "numbers_with_elongated_ticks": np.arange(-10, 10.1, 2)
#             },
#             tips=False
#         )
#
#         # Curves
#         curve1 = axes.plot(lambda x: np.sin(x), color=BLUE)
#         curve2 = axes.plot(lambda x: np.cos(x), color=RED)
#         area = axes.get_area(curve1, x_range=[-3, 3], color=BLUE, opacity=0.5)
#
#         # Labels
#         curve1_label1 = axes.get_graph_label(curve1, label="\\sin(x)", x_val=-10, direction=UP / 2)
#         curve1_label2 = axes.get_graph_label(curve2, label="\\cos(x)", x_val=-10, direction=DOWN)
#
#         # === New Part: Text moving along sine curve ===
#         text1 = Text("Area Under the curve", font_size=32, color=YELLOW)
#         t_tracker = ValueTracker(-10)  # start at x=-10
#
#         moving_text = always_redraw(
#             lambda: text1.move_to(
#                 axes.c2p(t_tracker.get_value(), np.sin(t_tracker.get_value())) + UP*0.4
#             )
#         )
#
#         # Animations
#         self.play(Create(axes))
#         self.wait(1)
#         self.play(Create(curve1))
#         self.wait(1)
#         self.play(Create(curve2))
#         self.add(curve1_label2)
#         self.wait(1)
#         self.play(FadeOut(curve2), FadeOut(curve1_label2))
#         self.add(curve1_label1)
#         self.wait(1)
#         self.play(Create(area))
#         self.wait(1)
#
#         # Play text gliding along sine curve
#         self.add(moving_text)
#         self.play(t_tracker.animate.set_value(10), run_time=6, rate_func=linear)
#         self.play(FadeOut(moving_text))
#         self.wait(2)
#
#
#         # Animate the text
#         self.play(FadeIn(text, shift=DOWN))  # fades in from top to position
#         self.play(text.animate.scale(1.2).set_color_by_gradient(YELLOW, ORANGE), run_time=1.5)  # scale + change gradient
#         self.play(text.animate.scale(0.85).set_color_by_gradient(GREEN, TEAL), run_time=1.5)   # scale down + new gradient
#         self.wait(2)
# Out:
# (process:3090): GLib-GObject-WARNING **: 17:55:29.236: cannot unreference class of invalid (unclassed) type '(NULL)'
# <video src="media/jupyter/SinAndCosFunctionPlot2@2025-10-01@17-55-31.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Class two on positioning and configuration

# %%
# %%manim -v WARNING -ql -r 1920,1080 Positioning
# from manim import *

# class Positioning(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         self.add(plane)

# %%
# %%manim -v WARNING -ql -i Positioning
# from manim import *

# class Positioning(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         self.add(plane)

# %%
# %%manim -v WARNING -ql -r 1080,1920 -i Positioning1
# class Positioning1(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         self.add(plane)

# %%
# %%manim -v WARNING -ql -i Positioning
# from manim import *

# class Positioning(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         self.add(plane)

# %%
# %%manim -v WARNING -ql  Positioning2
# class Positioning2(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         #self.add(plane)
#         self.play(Create(plane))
#
#         # next_to
#         red_dot = Dot(color=RED)
#         green_dot = Dot(color=GREEN)
#         green_dot.next_to(red_dot,RIGHT)
#         # self.add(red_dot, green_dot)
#         self.play(Create(red_dot), Create(green_dot))
#
#         # shift
#         s = Square(color=GREEN)
#         s1 = Square(color=ORANGE)
#         self.play(Create(s1), Create(s))
#         self.play(s1.animate.shift(2*UP + 4*RIGHT))
#         # s.shift(2*UP + 4*RIGHT)
#         #self.add(s1,s)
#
#         # move_to
#         # c1 = Circle(color=PURE_BLUE)
#         # c1.move_to(RIGHT)
#         c1 = Circle(color=YELLOW)
#         self.play(Create(c1))
#         self.play(c1.animate.move_to([-3,-2,0]))
#         #c1.move_to([-3,-2,0])
#         #self.add(c1)
#
#         #align_to
#         c2 = Circle(radius=0.5, color=RED, fill_opacity=0.5)
#         self.play(Create(c2))
#         c3 = c2.copy().set_color(BLUE)
#         self.play(Create(c3))
#         c4 = c2.copy().set_color(PINK)
#         self.play(Create(c4))
#         self.play(c2.animate.align_to(s1, UP))
#         self.play(c3.animate.align_to(s1, RIGHT))
#         self.play(c4.animate.align_to(s1, UP+RIGHT))
#         # c2.align_to(s, UP)
#         # c3.align_to(s, RIGHT)
#         # c4.align_to(s, UP+RIGHT)
#         # self.add(c2,c3,c4 )
#
#         #lets do text align_to for each circle we drew
#         tex2= Text('this is aligned to UP of square', font_size=24, color=WHITE)
#
#         # Start at top of orange square
#         tex2.move_to(s1.get_top() + UP*0.3)
#
#         self.add(tex2)  # make sure it's visible
#         self.wait(0.5)
#
#         # Animate moving to align with the top of red circle
#         self.play(tex2.animate.next_to(c2, UP))
#
#
#         self.wait(3)
# Out:
# <video src="media/jupyter/Positioning2@2025-10-03@18-02-53.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### 🔑 Key Difference between `shift()` and `next_to()` in Manim
#
# - **`shift()`**
#   - Moves the object by a fixed vector (absolute units of the `NumberPlane`).
#   - Example:
#     ```python
#     dot.shift(RIGHT)  # moves the dot by 1 unit to the right
#     ```
#
# - **`next_to()`**
#   - Positions one object relative to another object's boundary, with an optional buffer (default = 0.25 units).
#   - Example:
#     ```python
#     dot2.next_to(dot1, RIGHT)  # places dot2 just to the right of dot1
#     ```

# %%
# %%manim -v WARNING -ql -i TextFromSquareToCircle
#
# class TextFromSquareToCircle(Scene):
#     def construct(self):
#         # Create shapes
#         square = Square(color=BLUE).shift(LEFT*3)
#         circle = Circle(color=GREEN).shift(RIGHT*3)
#
#         # Create text (start inside the square)
#         word = Text("Hello", font_size=64).move_to(square.get_center())
#
#         # Show square and circle
#         self.play(Create(square), Create(circle))
#
#         # Show text inside the square
#         self.play(Write(word))
#
#         # Animate moving the text to the circle
#         self.play(word.animate.move_to(circle.get_center()))
#
#         # Keep final frame
#         self.wait(2)
# Out:
# [10/03/25 14:43:07] WARNING  --save_as_gif is deprecated, please use --format=gif instead!           ]8;id=939814;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py\commands.py]8;;\:]8;id=326830;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py#50\50]8;;\
# (process:4316): GLib-GObject-WARNING **: 14:43:07.393: cannot unreference class of invalid (unclassed) type '(NULL)'

# %%
# %%manim -v WARNING -ql -i PikachuDotsFull
# from manim import *
# import numpy as np
#
# class PikachuDotsFull(Scene):
#     def construct(self):
#         dot_radius = 0.08
#
#         # Step 1: create a grid of dots
#         x_vals = np.linspace(-3, 3, 30)  # more dots for width
#         y_vals = np.linspace(-3, 3, 30)  # more dots for height
#
#         dots = VGroup()
#
#         for x in x_vals:
#             for y in y_vals:
#                 # Equation for a rough Pikachu shape (approximate using inequalities)
#                 # Head & body
#                 if (x**2 + (y-0.5)**2 < 4):
#                     # Cheeks
#                     if (x < -1.2 and y < 0 and y > -1):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=RED))
#                     elif (x > 1.2 and y < 0 and y > -1):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=RED))
#                     # Eyes
#                     elif (abs(x) < 0.3 and y > 0.5 and y < 1.2):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=BLACK))
#                     # Ears (triangular approximation)
#                     elif ((x < -1.5 and y > 1.5) or (x > 1.5 and y > 1.5)):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=BLACK))
#                     else:
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=YELLOW))
#
#         # Step 2: Animate all dots appearing
#         self.play(LaggedStartMap(FadeIn, dots, lag_ratio=0.005))
#         self.wait(3)
# Out:
# [10/03/25 17:37:57] WARNING  --save_as_gif is deprecated, please use --format=gif instead!           ]8;id=536873;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py\commands.py]8;;\:]8;id=389682;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py#50\50]8;;\

# %%
# %%manim -v WARNING -ql -i PikachuDetailedDots1
# from manim import *
# import numpy as np
#
# class PikachuDetailedDots1(Scene):
#     def construct(self):
#         dot_radius = 0.05  # smaller dot for more detail
#
#         # Fine grid for smoothness
#         x_vals = np.linspace(-3, 3, 80)
#         y_vals = np.linspace(-3, 3, 80)
#
#         dots = VGroup()
#
#         for x in x_vals:
#             for y in y_vals:
#                 # --- BODY (yellow) ---
#                 # ellipse-like main body
#                 if ((x**2)/4 + ((y+0.5)**2)/5 <= 1):
#                     # --- EYES (black) ---
#                     if (-0.5 <= x <= -0.2 and 0.5 <= y <= 1.2) or (0.2 <= x <= 0.5 and 0.5 <= y <= 1.2):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=BLACK))
#                     # --- CHEEKS (red) ---
#                     elif (-1.2 <= x <= -0.8 and -1 <= y <= -0.5) or (0.8 <= x <= 1.2 and -1 <= y <= -0.5):
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=RED))
#                     # --- BODY YELLOW ---
#                     else:
#                         dots.add(Dot([x,y,0], radius=dot_radius, color=YELLOW))
#
#                 # --- EARS (black tips) ---
#                 elif ((x <= -1.5 and y >= 1.5 and y <= 3) or (x >= 1.5 and y >= 1.5 and y <= 3)):
#                     dots.add(Dot([x,y,0], radius=dot_radius, color=BLACK))
#
#         # Animate dots appearing
#         self.play(LaggedStartMap(FadeIn, dots, lag_ratio=0.001))
#         self.wait(3)
# Out:
# [10/03/25 17:41:37] WARNING  --save_as_gif is deprecated, please use --format=gif instead!           ]8;id=490063;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py\commands.py]8;;\:]8;id=377708;file:///Users/aakashkhanal/anaconda3/lib/python3.11/site-packages/manim/cli/render/commands.py#50\50]8;;\
